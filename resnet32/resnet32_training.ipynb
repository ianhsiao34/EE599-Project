# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.ao.quantization import QuantStub, DeQuantStub
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from collections import OrderedDict

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device={device}")
# Out:
# Device=cuda

# %%
from models.cifar_resnet32 import ResNet32

model = ResNet32().to('cuda' if torch.cuda.is_available() else 'cpu')
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.transforms.autoaugment import AutoAugment, AutoAugmentPolicy

def load_dataset(path='./data', batch_size=64, num_workers=4):
    print("Loading the CIFAR10 dataset")

    transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        AutoAugment(policy=AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010)),
    ])

    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010)),
    ])

    train_dataset = datasets.CIFAR10(root=path, train=True, download=True, transform=transform)
    test_dataset  = datasets.CIFAR10(root=path, train=False, download=True, transform=test_transform)

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,   # <-- use workers
        pin_memory=True,           # <-- good for GPU
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size * 2, # eval can use bigger batch
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True,
    )

    print(
        f"Loaded train data: {len(train_loader.dataset)} samples, {len(train_loader)} batches\n"
        f"Loaded test data:  {len(test_loader.dataset)} samples, {len(test_loader)} batches"
    )

    return train_loader, test_loader

# %%
train_loader, test_loader = load_dataset(batch_size=128, num_workers=2)
# Out:
# Loading the CIFAR10 dataset
# Loaded train data: 50000 samples, 391 batches
# Loaded test data:  10000 samples, 40 batches

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_metrics(metrics):
  train_losses = metrics.get('train_loss',None)
  test_losses = metrics.get('test_loss',None)
  train_accs = metrics.get('train_acc',None)
  test_accs = metrics.get('test_acc',None)

  epochs = range(1, len(train_losses) + 1)

  plt.figure(figsize=(12, 5))

  # Loss Graph
  plt.subplot(1, 2, 1)
  if train_losses:
    plt.plot(epochs, train_losses, label='Train Loss', marker='o')
  if test_losses:
    plt.plot(epochs, test_losses, label='Test Loss', marker='s')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.title('Training vs Test Loss')
  plt.legend()
  plt.grid(True, linestyle='--', alpha=0.6)

  # Accuracy Graph
  plt.subplot(1, 2, 2)
  if train_accs:
    plt.plot(epochs, train_accs, label='Train Accuracy', marker='o')
  if test_accs:
    plt.plot(epochs, test_accs, label='Test Accuracy', marker='s')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy (%)')
  plt.title('Training vs Test Accuracy')
  plt.legend()
  plt.grid(True, linestyle='--', alpha=0.6)

  plt.tight_layout()
  plt.show()

def plot_weight_histogram(model, bins=50):
  all_weights = []

  for name, module in model.named_modules():
      if isinstance(module, (torch.nn.Conv2d, torch.nn.Linear)):
          weights = module.weight.detach().cpu().numpy().flatten()
          all_weights.extend(weights)

  all_weights = np.array(all_weights)

  plt.figure(figsize=(8,6))
  plt.hist(all_weights, bins=bins, color='skyblue', edgecolor='black')
  plt.title("Weight Distribution Histogram")
  plt.xlabel("Weight Value")
  plt.ylabel("Frequency")
  plt.grid(True, alpha=0.3)
  plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train_model(model,
                train_loader,
                test_loader,
                device='cpu',
                epochs=10,
                lr=1e-3,
                train=True,
                test=True):
    model.to(device)

    metrics = {
        "train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        model.parameters(),
        lr=lr,
        momentum=0.9,
        weight_decay=5e-4
    )

    for e in range(epochs):
        print(f"Epoch [{e+1}/{epochs}] ", end='')

        # ---- TRAIN ----
        if train:
            model.train()
            train_loss, total_examples, correct = 0.0, 0, 0

            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                train_loss += loss.item() * labels.size(0)
                _, pred_ind = outputs.max(1)
                total_examples += labels.size(0)
                correct += pred_ind.eq(labels).sum().item()

            train_loss /= total_examples
            train_acc = 100.0 * correct / total_examples

            metrics["train_loss"].append(train_loss)
            metrics["train_acc"].append(train_acc)

            print(f"Train Loss: {train_loss:.4f}, "
                  f"Train Acc: {train_acc:.2f}% ", end='')

        # ---- TEST / VALIDATION ----
        if test:
            model.eval()
            test_loss, total_examples, correct = 0.0, 0, 0

            with torch.no_grad():
                for inputs, labels in test_loader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    test_loss += loss.item() * labels.size(0)
                    _, pred_ind = outputs.max(1)
                    total_examples += labels.size(0)
                    correct += pred_ind.eq(labels).sum().item()

            test_loss /= total_examples
            test_acc = 100.0 * correct / total_examples

            metrics["test_loss"].append(test_loss)
            metrics["test_acc"].append(test_acc)

            print(f"Test/Val Loss: {test_loss:.4f}, "
                  f"Test/Val Acc: {test_acc:.2f}%")

    return metrics

# %%
from models.cifar_resnet32 import ResNet32
import torch

model = ResNet32(num_classes=10)
model.load_state_dict(torch.load("checkpoints/resnet32_fp32_best.pt", map_location="cpu"))

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total Parameters: {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")

model_size_MB = total_params * 4 / (1024 ** 2)
print(f"Model Size (FP32): {model_size_MB:.2f} MB")
# Out:
# Total Parameters: 466,906
# Trainable Parameters: 466,906
# Model Size (FP32): 1.78 MB

# %%
print(f"Running on: {device}")
# Out:
# Running on: cuda

# %%
train, test = True, True
epochs = 100
fp32_metrics = train_model(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    train=train,
    test=test,
    device=device,
    epochs=epochs
)
# Out:
# Epoch [1/100] Train Loss: 0.6868, Train Acc: 76.55% Test/Val Loss: 0.3985, Test/Val Acc: 86.59%
# Epoch [2/100] Train Loss: 0.6179, Train Acc: 78.83% Test/Val Loss: 0.3801, Test/Val Acc: 87.04%
# Epoch [3/100] Train Loss: 0.5901, Train Acc: 79.93% Test/Val Loss: 0.3709, Test/Val Acc: 87.15%
# Epoch [4/100] Train Loss: 0.5703, Train Acc: 80.47% Test/Val Loss: 0.3654, Test/Val Acc: 87.41%
# Epoch [5/100] Train Loss: 0.5610, Train Acc: 80.77% Test/Val Loss: 0.3609, Test/Val Acc: 87.67%
# Epoch [6/100] Train Loss: 0.5525, Train Acc: 80.98% Test/Val Loss: 0.3558, Test/Val Acc: 87.89%
# Epoch [7/100] Train Loss: 0.5372, Train Acc: 81.71% Test/Val Loss: 0.3543, Test/Val Acc: 87.98%
# Epoch [8/100] Train Loss: 0.5283, Train Acc: 82.02% Test/Val Loss: 0.3510, Test/Val Acc: 88.19%
# Epoch [9/100] Train Loss: 0.5319, Train Acc: 81.78% Test/Val Loss: 0.3485, Test/Val Acc: 88.18%
# Epoch [10/100] Train Loss: 0.5174, Train Acc: 82.39% Test/Val Loss: 0.3462, Test/Val Acc: 88.11%
# Epoch [11/100] Train Loss: 0.5142, Train Acc: 82.34% Test/Val Loss: 0.3430, Test/Val Acc: 88.30%
# Epoch [12/100] Train Loss: 0.5096, Train Acc: 82.60% Test/Val Loss: 0.3407, Test/Val Acc: 88.48%
# Epoch [13/100] Train Loss: 0.5084, Train Acc: 82.47% Test/Val Loss: 0.3373, Test/Val Acc: 88.48%
# Epoch [84/100] Train Loss: 0.3673, Train Acc: 87.26% Test/Val Loss: 0.2776, Test/Val Acc: 90.45%
# Epoch [85/100] Train Loss: 0.3679, Train Acc: 87.36% Test/Val Loss: 0.2746, Test/Val Acc: 90.47%
# Epoch [86/100] Train Loss: 0.3681, Train Acc: 87.42% Test/Val Loss: 0.2756, Test/Val Acc: 90.57%
# Epoch [87/100] Train Loss: 0.3681, Train Acc: 87.26% Test/Val Loss: 0.2770, Test/Val Acc: 90.60%
# Epoch [88/100] Train Loss: 0.3628, Train Acc: 87.40% Test/Val Loss: 0.2796, Test/Val Acc: 90.40%
# Epoch [89/100] Train Loss: 0.3592, Train Acc: 87.67% Test/Val Loss: 0.2755, Test/Val Acc: 90.50%
# Epoch [90/100] Train Loss: 0.3621, Train Acc: 87.45% Test/Val Loss: 0.2759, Test/Val Acc: 90.56%
# Epoch [91/100] Train Loss: 0.3607, Train Acc: 87.53% Test/Val Loss: 0.2759, Test/Val Acc: 90.74%
# Epoch [92/100] Train Loss: 0.3551, Train Acc: 87.77% Test/Val Loss: 0.2729, Test/Val Acc: 90.56%
# Epoch [93/100] Train Loss: 0.3566, Train Acc: 87.71% Test/Val Loss: 0.2755, Test/Val Acc: 90.53%
# Epoch [94/100] Train Loss: 0.3545, Train Acc: 87.83% Test/Val Loss: 0.2724, Test/Val Acc: 90.56%
# Epoch [95/100] Train Loss: 0.3562, Train Acc: 87.73% Test/Val Loss: 0.2721, Test/Val Acc: 90.68%
# Epoch [96/100] Train Loss: 0.3551, Train Acc: 87.82% Test/Val Loss: 0.2735, Test/Val Acc: 90.55%
# Epoch [97/100] Train Loss: 0.3489, Train Acc: 87.96% Test/Val Loss: 0.2713, Test/Val Acc: 90.78%
# Epoch [98/100] Train Loss: 0.3496, Train Acc: 87.90% Test/Val Loss: 0.2704, Test/Val Acc: 90.78%
# Epoch [99/100] Train Loss: 0.3509, Train Acc: 88.04% Test/Val Loss: 0.2712, Test/Val Acc: 90.65%
# Epoch [100/100] Train Loss: 0.3437, Train Acc: 88.22% Test/Val Loss: 0.2723, Test/Val Acc: 90.65%

# %%
torch.save(model.state_dict(), "checkpoints/resnet32_fp32_trained.pt")
torch.save(fp32_metrics, "checkpoints/resnet32_fp32_metrics.pt")

# %%
metrics = torch.load("checkpoints/resnet32_fp32_metrics.pt")
plot_metrics(metrics)
plot_weight_histogram(model)

# %%
model = ResNet32(num_classes=10)
model.load_state_dict(torch.load("checkpoints/resnet32_fp32_best.pt"))
model.train()

#model = SqueezeNetCIFAR10()
#model.load_model("squeezenet_dataaug_cifar10_fp32.pth", device=device)
#model.train()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
import copy
import torch.nn.utils.prune as prune
import torch

prune_levels = [0.1, 0.3, 0.5, 0.7]
results = []

# Per–sparsity hyperparams (tweak these if you like)
prune_cfg = {
    0.1: {"lr": 1e-2, "epochs": 10},   # light pruning
    0.3: {"lr": 2e-2, "epochs": 15},   # medium
    0.5: {"lr": 3e-2, "epochs": 20},   # heavy
    0.7: {"lr": 5e-2, "epochs": 25},   # very heavy
}

for p in prune_levels:
    cfg = prune_cfg[p]
    lr = cfg["lr"]
    epochs = cfg["epochs"]

    print(f"\n=== Pruning {p*100:.0f}% of weights (global L1) ===")
    print(f"Using lr={lr}, epochs={epochs}")

    # 1) Start from the trained FP32 baseline
    m = copy.deepcopy(model)  # 'model' = trained FP32 ResNet32

    # 2) Collect all Conv/Linear weights to prune
    parameters_to_prune = []
    for module in m.modules():
        if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
            parameters_to_prune.append((module, "weight"))

    prune.global_unstructured(
        parameters_to_prune,
        pruning_method=prune.L1Unstructured,
        amount=p,
    )

    # 3) Fine-tune the pruned model
    metrics = train_model(
        model=m,
        train_loader=train_loader,
        test_loader=test_loader,
        device=device,
        epochs=epochs,
        lr=lr,
        train=True,
        test=True,
    )

    # 4) Remove pruning reparam so weights are plain tensors
    for module in m.modules():
        if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
            if hasattr(module, "weight_orig"):
                prune.remove(module, "weight")

    # 5) Save the pruned fine-tuned model + metrics
    percent = int(p * 100)
    model_path   = f"checkpoints/resnet32_pruned_{percent}pct.pt"
    metrics_path = f"checkpoints/resnet32_pruned_{percent}pct_metrics.pt"

    torch.save(m.state_dict(), model_path)
    torch.save(metrics, metrics_path)

    print(f"Saved pruned model to {model_path}")
    print(f"Saved metrics to    {metrics_path}")

    results.append((p, metrics))
# Out:
# === Pruning 10% of weights (global L1) ===
# Using lr=0.01, epochs=10
# Epoch [1/10] Train Loss: 0.5983, Train Acc: 79.58% Test/Val Loss: 0.3669, Test/Val Acc: 87.27%
# Epoch [2/10] Train Loss: 0.5290, Train Acc: 81.74% Test/Val Loss: 0.3519, Test/Val Acc: 87.94%
# Epoch [3/10] Train Loss: 0.5087, Train Acc: 82.55% Test/Val Loss: 0.3414, Test/Val Acc: 88.32%
# Epoch [4/10] Train Loss: 0.4857, Train Acc: 83.49% Test/Val Loss: 0.3446, Test/Val Acc: 88.64%
# Epoch [5/10] Train Loss: 0.4764, Train Acc: 83.44% Test/Val Loss: 0.3346, Test/Val Acc: 88.69%
# Epoch [6/10] Train Loss: 0.4649, Train Acc: 83.86% Test/Val Loss: 0.3224, Test/Val Acc: 88.70%
# Epoch [7/10] Train Loss: 0.4607, Train Acc: 84.18% Test/Val Loss: 0.3245, Test/Val Acc: 89.00%
# Epoch [8/10] Train Loss: 0.4519, Train Acc: 84.48% Test/Val Loss: 0.3389, Test/Val Acc: 88.59%
# Epoch [9/10] Train Loss: 0.4526, Train Acc: 84.39% Test/Val Loss: 0.3198, Test/Val Acc: 89.13%
# Epoch [10/10] Train Loss: 0.4399, Train Acc: 84.88% Test/Val Loss: 0.3208, Test/Val Acc: 89.31%
# Saved pruned model to checkpoints/resnet32_pruned_10pct.pt
# Saved metrics to    checkpoints/resnet32_pruned_10pct_metrics.pt
#
# === Pruning 30% of weights (global L1) ===
# Using lr=0.02, epochs=15
# Epoch [1/15] Train Loss: 0.5907, Train Acc: 79.84% Test/Val Loss: 0.4052, Test/Val Acc: 86.53%
# Epoch [2/15] Train Loss: 0.5380, Train Acc: 81.42% Test/Val Loss: 0.3655, Test/Val Acc: 87.79%
# Epoch [3/15] Train Loss: 0.5121, Train Acc: 82.27% Test/Val Loss: 0.3534, Test/Val Acc: 88.09%
# Epoch [4/15] Train Loss: 0.5063, Train Acc: 82.56% Test/Val Loss: 0.3674, Test/Val Acc: 87.42%
# Epoch [5/15] Train Loss: 0.5022, Train Acc: 82.69% Test/Val Loss: 0.4036, Test/Val Acc: 86.24%
# Epoch [6/15] Train Loss: 0.4928, Train Acc: 83.10% Test/Val Loss: 0.3618, Test/Val Acc: 87.73%
# Epoch [7/15] Train Loss: 0.4863, Train Acc: 83.36% Test/Val Loss: 0.3889, Test/Val Acc: 87.03%
# Epoch [8/15] Train Loss: 0.4788, Train Acc: 83.44% Test/Val Loss: 0.3852, Test/Val Acc: 87.03%
# Epoch [9/15] Train Loss: 0.4780, Train Acc: 83.52% Test/Val Loss: 0.4210, Test/Val Acc: 85.68%
# Epoch [10/15] Train Loss: 0.4856, Train Acc: 83.30% Test/Val Loss: 0.3740, Test/Val Acc: 87.52%
# Epoch [11/15] Train Loss: 0.4717, Train Acc: 83.74% Test/Val Loss: 0.3619, Test/Val Acc: 87.74%
# Epoch [12/15] Train Loss: 0.4739, Train Acc: 83.61% Test/Val Loss: 0.3985, Test/Val Acc: 86.75%
# Epoch [13/15] Train Loss: 0.4714, Train Acc: 83.81% Test/Val Loss: 0.4133, Test/Val Acc: 85.92%
# Epoch [14/15] Train Loss: 0.4702, Train Acc: 83.89% Test/Val Loss: 0.4236, Test/Val Acc: 86.34%
# Epoch [15/15] Train Loss: 0.4772, Train Acc: 83.66% Test/Val Loss: 0.3829, Test/Val Acc: 86.88%
# Saved pruned model to checkpoints/resnet32_pruned_30pct.pt
# Saved metrics to    checkpoints/resnet32_pruned_30pct_metrics.pt
#
# === Pruning 50% of weights (global L1) ===
# Using lr=0.03, epochs=20
# Epoch [1/20] Train Loss: 0.5926, Train Acc: 79.58% Test/Val Loss: 0.3795, Test/Val Acc: 87.06%
# Epoch [2/20] Train Loss: 0.5535, Train Acc: 80.86% Test/Val Loss: 0.4500, Test/Val Acc: 84.95%
# Epoch [3/20] Train Loss: 0.5417, Train Acc: 81.62% Test/Val Loss: 0.3800, Test/Val Acc: 86.79%
# Epoch [4/20] Train Loss: 0.5330, Train Acc: 81.61% Test/Val Loss: 0.3973, Test/Val Acc: 86.93%
# Epoch [5/20] Train Loss: 0.5224, Train Acc: 82.01% Test/Val Loss: 0.4023, Test/Val Acc: 86.18%
# Epoch [6/20] Train Loss: 0.5268, Train Acc: 81.82% Test/Val Loss: 0.4391, Test/Val Acc: 85.18%
# Epoch [7/20] Train Loss: 0.5207, Train Acc: 81.98% Test/Val Loss: 0.4316, Test/Val Acc: 86.15%
# Epoch [8/20] Train Loss: 0.5250, Train Acc: 81.77% Test/Val Loss: 0.4333, Test/Val Acc: 85.21%
# Epoch [9/20] Train Loss: 0.5194, Train Acc: 82.10% Test/Val Loss: 0.4523, Test/Val Acc: 84.93%
# Epoch [10/20] Train Loss: 0.5167, Train Acc: 82.17% Test/Val Loss: 0.4160, Test/Val Acc: 86.01%
# Epoch [11/20] Train Loss: 0.5154, Train Acc: 82.28% Test/Val Loss: 0.4620, Test/Val Acc: 84.57%
# Epoch [12/20] Train Loss: 0.5186, Train Acc: 81.99% Test/Val Loss: 0.4652, Test/Val Acc: 84.89%
# Epoch [13/20] Train Loss: 0.5163, Train Acc: 82.18% Test/Val Loss: 0.4429, Test/Val Acc: 85.32%
# Epoch [14/20] Train Loss: 0.5080, Train Acc: 82.58% Test/Val Loss: 0.3846, Test/Val Acc: 86.92%
# Epoch [15/20] Train Loss: 0.5109, Train Acc: 82.30% Test/Val Loss: 0.4358, Test/Val Acc: 85.52%
# Epoch [16/20] Train Loss: 0.5090, Train Acc: 82.42% Test/Val Loss: 0.4193, Test/Val Acc: 85.78%
# Epoch [17/20] Train Loss: 0.5096, Train Acc: 82.34% Test/Val Loss: 0.4253, Test/Val Acc: 85.08%
# Epoch [18/20] Train Loss: 0.5013, Train Acc: 82.84% Test/Val Loss: 0.4373, Test/Val Acc: 85.00%
# Epoch [19/20] Train Loss: 0.5002, Train Acc: 82.68% Test/Val Loss: 0.4629, Test/Val Acc: 84.01%
# Epoch [20/20] Train Loss: 0.5017, Train Acc: 82.60% Test/Val Loss: 0.6151, Test/Val Acc: 80.30%
# Saved pruned model to checkpoints/resnet32_pruned_50pct.pt
# Saved metrics to    checkpoints/resnet32_pruned_50pct_metrics.pt
#
# === Pruning 70% of weights (global L1) ===
# Using lr=0.05, epochs=25
# Epoch [1/25] Train Loss: 0.6413, Train Acc: 78.25% Test/Val Loss: 0.5557, Test/Val Acc: 82.31%
# Epoch [2/25] Train Loss: 0.5985, Train Acc: 79.66% Test/Val Loss: 0.5053, Test/Val Acc: 82.80%
# Epoch [3/25] Train Loss: 0.5916, Train Acc: 79.45% Test/Val Loss: 0.5903, Test/Val Acc: 80.93%
# Epoch [4/25] Train Loss: 0.5925, Train Acc: 79.65% Test/Val Loss: 0.4806, Test/Val Acc: 83.86%
# Epoch [5/25] Train Loss: 0.5917, Train Acc: 79.56% Test/Val Loss: 0.5201, Test/Val Acc: 82.72%
# Epoch [6/25] Train Loss: 0.5893, Train Acc: 79.72% Test/Val Loss: 0.4979, Test/Val Acc: 83.25%
# Epoch [7/25] Train Loss: 0.5924, Train Acc: 79.63% Test/Val Loss: 0.5358, Test/Val Acc: 82.12%
# Epoch [8/25] Train Loss: 0.5816, Train Acc: 80.11% Test/Val Loss: 0.5285, Test/Val Acc: 82.83%
# Epoch [9/25] Train Loss: 0.5812, Train Acc: 80.00% Test/Val Loss: 0.5103, Test/Val Acc: 82.80%
# Epoch [10/25] Train Loss: 0.5858, Train Acc: 79.87% Test/Val Loss: 0.4815, Test/Val Acc: 83.73%
# Epoch [11/25] Train Loss: 0.5798, Train Acc: 80.04% Test/Val Loss: 0.5727, Test/Val Acc: 80.95%
# Epoch [12/25] Train Loss: 0.5761, Train Acc: 80.11% Test/Val Loss: 0.5028, Test/Val Acc: 83.49%
# Epoch [13/25] Train Loss: 0.5730, Train Acc: 80.35% Test/Val Loss: 0.4561, Test/Val Acc: 84.36%
# Epoch [14/25] Train Loss: 0.5750, Train Acc: 80.30% Test/Val Loss: 0.6449, Test/Val Acc: 78.47%
# Epoch [15/25] Train Loss: 0.5718, Train Acc: 80.38% Test/Val Loss: 0.4539, Test/Val Acc: 84.43%
# Epoch [16/25] Train Loss: 0.5738, Train Acc: 80.17% Test/Val Loss: 0.4438, Test/Val Acc: 84.70%
# Epoch [17/25] Train Loss: 0.5673, Train Acc: 80.24% Test/Val Loss: 0.4613, Test/Val Acc: 84.31%
# Epoch [18/25] Train Loss: 0.5710, Train Acc: 80.28% Test/Val Loss: 0.5122, Test/Val Acc: 82.84%
# Epoch [19/25] Train Loss: 0.5656, Train Acc: 80.36% Test/Val Loss: 0.4772, Test/Val Acc: 84.01%
# Epoch [20/25] Train Loss: 0.5642, Train Acc: 80.50% Test/Val Loss: 0.4475, Test/Val Acc: 84.34%
# Epoch [21/25] Train Loss: 0.5691, Train Acc: 80.52% Test/Val Loss: 0.4701, Test/Val Acc: 84.43%
# Epoch [22/25] Train Loss: 0.5612, Train Acc: 80.73% Test/Val Loss: 0.6748, Test/Val Acc: 78.50%
# Epoch [23/25] Train Loss: 0.5645, Train Acc: 80.56% Test/Val Loss: 0.5051, Test/Val Acc: 82.92%
# Epoch [24/25] Train Loss: 0.5625, Train Acc: 80.67% Test/Val Loss: 0.4889, Test/Val Acc: 83.82%
# Epoch [25/25] Train Loss: 0.5610, Train Acc: 80.41% Test/Val Loss: 0.5108, Test/Val Acc: 83.24%
# Saved pruned model to checkpoints/resnet32_pruned_70pct.pt
# Saved metrics to    checkpoints/resnet32_pruned_70pct_metrics.pt

# %%
for p, metrics in results:
    print(f"Metrics for pruning with p={p}")
    plot_metrics(metrics)
# Out:
# Metrics for pruning with p=0.1
# Metrics for pruning with p=0.3
# Metrics for pruning with p=0.5
# Metrics for pruning with p=0.7

# %%
import torch
import torch.nn as nn
from torch.ao.quantization import get_default_qat_qconfig
from torch.ao.quantization.quantize_fx import prepare_qat_fx, convert_fx

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1) Start from your pruned FP32 model
model_qat = ResNet32(num_classes=10)
state_dict = torch.load("checkpoints/resnet32_pruned_10pct.pt",
                        map_location="cpu")
model_qat.load_state_dict(state_dict)

# For QAT you want the model in TRAIN mode when preparing
model_qat.train()

# 2) Example input for FX (shape must match CIFAR-10)
example_inputs = (torch.randn(1, 3, 32, 32),)

# 3) QAT config: fake-quant based on fbgemm backend
qconfig_dict = {"": get_default_qat_qconfig("fbgemm")}

# 4) Prepare the model for QAT (inserts fake quant + observers)
model_qat_prepared = prepare_qat_fx(model_qat, qconfig_dict,
                                    example_inputs=example_inputs)

# Move to GPU for training if available
model_qat_prepared.to(device)
model_qat_prepared.train()
print("QAT model ready on:", device)
# Out:
# /tmp/SLURM_5221364/ipykernel_3531825/4261390116.py:24: DeprecationWarning: torch.ao.quantization is deprecated and will be removed in 2.10.
# For migrations of users:
# 1. Eager mode quantization (torch.ao.quantization.quantize, torch.ao.quantization.quantize_dynamic), please migrate to use torchao eager mode quantize_ API instead
# 2. FX graph mode quantization (torch.ao.quantization.quantize_fx.prepare_fx,torch.ao.quantization.quantize_fx.convert_fx, please migrate to use torchao pt2e quantization API instead (prepare_pt2e, convert_pt2e)
# 3. pt2e quantization has been migrated to torchao (https://github.com/pytorch/ao/tree/main/torchao/quantization/pt2e)
# see https://github.com/pytorch/ao/issues/2259 for more details
#   model_qat_prepared = prepare_qat_fx(model_qat, qconfig_dict,
# QAT model ready on: cuda
# /home1/ihsiao/.conda/envs/ee599/lib/python3.12/site-packages/torch/ao/quantization/quantize_fx.py:146: FutureWarning: Passing a QConfig dictionary to prepare is deprecated and will not be supported in a future version. Please pass in a QConfigMapping instead.
#   prepared = prepare(
# /home1/ihsiao/.conda/envs/ee599/lib/python3.12/site-packages/torch/ao/quantization/observer.py:246: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(

# %%
qat_metrics = train_model(
    model=model_qat_prepared,
    train_loader=train_loader,
    test_loader=test_loader,
    device=device,
    epochs=20,    # 20–30 epochs is typical for QAT fine-tune
    lr=1e-3,      # usually lower LR than baseline
    train=True,
    test=True,
)
# Out:
# Epoch [1/20] Train Loss: 0.4081, Train Acc: 85.97% Test/Val Loss: 0.2896, Test/Val Acc: 90.33%
# Epoch [2/20] Train Loss: 0.3985, Train Acc: 86.24% Test/Val Loss: 0.2865, Test/Val Acc: 90.29%
# Epoch [3/20] Train Loss: 0.3933, Train Acc: 86.45% Test/Val Loss: 0.2849, Test/Val Acc: 90.36%
# Epoch [4/20] Train Loss: 0.3843, Train Acc: 86.78% Test/Val Loss: 0.2853, Test/Val Acc: 90.46%
# Epoch [5/20] Train Loss: 0.3873, Train Acc: 86.80% Test/Val Loss: 0.2854, Test/Val Acc: 90.43%
# Epoch [6/20] Train Loss: 0.3813, Train Acc: 87.03% Test/Val Loss: 0.2839, Test/Val Acc: 90.24%
# Epoch [7/20] Train Loss: 0.3790, Train Acc: 87.06% Test/Val Loss: 0.2803, Test/Val Acc: 90.56%
# Epoch [8/20] Train Loss: 0.3793, Train Acc: 86.98% Test/Val Loss: 0.2808, Test/Val Acc: 90.50%
# Epoch [9/20] Train Loss: 0.3762, Train Acc: 87.09% Test/Val Loss: 0.2777, Test/Val Acc: 90.74%
# Epoch [10/20] Train Loss: 0.3741, Train Acc: 86.97% Test/Val Loss: 0.2800, Test/Val Acc: 90.37%
# Epoch [11/20] Train Loss: 0.3755, Train Acc: 86.99% Test/Val Loss: 0.2817, Test/Val Acc: 90.61%
# Epoch [12/20] Train Loss: 0.3719, Train Acc: 87.15% Test/Val Loss: 0.2787, Test/Val Acc: 90.55%
# Epoch [13/20] Train Loss: 0.3718, Train Acc: 87.18% Test/Val Loss: 0.2787, Test/Val Acc: 90.53%
# Epoch [14/20] Train Loss: 0.3706, Train Acc: 87.14% Test/Val Loss: 0.2787, Test/Val Acc: 90.41%
# Epoch [15/20] Train Loss: 0.3670, Train Acc: 87.31% Test/Val Loss: 0.2791, Test/Val Acc: 90.48%
# Epoch [16/20] Train Loss: 0.3706, Train Acc: 87.24% Test/Val Loss: 0.2752, Test/Val Acc: 90.37%
# Epoch [17/20] Train Loss: 0.3676, Train Acc: 87.43% Test/Val Loss: 0.2744, Test/Val Acc: 90.57%
# Epoch [18/20] Train Loss: 0.3679, Train Acc: 87.36% Test/Val Loss: 0.2766, Test/Val Acc: 90.54%
# Epoch [19/20] Train Loss: 0.3683, Train Acc: 87.25% Test/Val Loss: 0.2757, Test/Val Acc: 90.80%
# Epoch [20/20] Train Loss: 0.3666, Train Acc: 87.19% Test/Val Loss: 0.2734, Test/Val Acc: 90.52%

# %%
from torch.ao.quantization.quantize_fx import convert_fx

# 5) Convert to real INT8 model (must be on CPU & eval)
model_qat_prepared.to("cpu")
model_qat_prepared.eval()

# (optional but common: disable observers & freeze BN if you haven’t already)
# from torch.ao.quantization import disable_observer
# from torch.ao.nn.intrinsic.qat import freeze_bn_stats
# model_qat_prepared.apply(torch.ao.quantization.disable_observer)
# model_qat_prepared.apply(torch.ao.quantization.freeze_bn_stats)

model_int8 = convert_fx(model_qat_prepared)   # <-- no example_inputs here

# Save INT8 model
torch.save(model_int8.state_dict(),
           "checkpoints/resnet32_pruned10_int8_qat_fx.pt")
print("Saved INT8 QAT model.")
# Out:
# /tmp/SLURM_5221364/ipykernel_3531825/3302863045.py:13: DeprecationWarning: torch.ao.quantization is deprecated and will be removed in 2.10.
# For migrations of users:
# 1. Eager mode quantization (torch.ao.quantization.quantize, torch.ao.quantization.quantize_dynamic), please migrate to use torchao eager mode quantize_ API instead
# 2. FX graph mode quantization (torch.ao.quantization.quantize_fx.prepare_fx,torch.ao.quantization.quantize_fx.convert_fx, please migrate to use torchao pt2e quantization API instead (prepare_pt2e, convert_pt2e)
# 3. pt2e quantization has been migrated to torchao (https://github.com/pytorch/ao/tree/main/torchao/quantization/pt2e)
# see https://github.com/pytorch/ao/issues/2259 for more details
#   model_int8 = convert_fx(model_qat_prepared)   # <-- no example_inputs here
# Saved INT8 QAT model.

# %%
def evaluate(model, test_loader):
    model.eval()
    model.to('cpu')
    correct, total = 0, 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to('cpu'), labels.to('cpu')
            outputs = model(images)
            _, pred = outputs.max(1)
            correct += pred.eq(labels).sum().item()
            total += labels.size(0)

    acc = 100.0 * correct / total
    return acc

acc = evaluate(model_int8,test_loader)
print(f"INT8 with QAT Test Accuracy: {acc}%")
# Out:
# INT8 with QAT Test Accuracy: 90.53%

# %%
import torch
from torch.ao.quantization import get_default_qconfig
from torch.ao.quantization.quantize_fx import prepare_fx, convert_fx

# 0. Use the same backend everywhere
torch.backends.quantized.engine = "fbgemm"

# 1. Load your pruned FP32 model **on CPU**
from models.cifar_resnet32 import ResNet32

model_fp32 = ResNet32(num_classes=10)
state = torch.load("checkpoints/resnet32_pruned_10pct.pt",
                   map_location="cpu")
model_fp32.load_state_dict(state)
model_fp32.eval()          # important
model_fp32.to("cpu")       # make sure it's really CPU

# 2. Prepare FX PTQ
example_inputs = (torch.randn(1, 3, 32, 32),)  # CPU tensor

qconfig_dict = {"": get_default_qconfig("fbgemm")}  # static PTQ config

model_ptq_prepared = prepare_fx(model_fp32, qconfig_dict, example_inputs)

# 3. Calibrate on a few training batches (CPU only)
from torch.utils.data import DataLoader

with torch.inference_mode():
    for i, (images, _) in enumerate(train_loader):
        images = images.to("cpu")
        model_ptq_prepared(images)
        if i == 20:      # ~20 batches is plenty
            break

# 4. Convert to real INT8
model_int8_ptq = convert_fx(model_ptq_prepared)
model_int8_ptq.eval()
model_int8_ptq.to("cpu")    # quantized ops are CPU-only
# Out:
# /tmp/SLURM_5221364/ipykernel_3531825/3964949556.py:23: DeprecationWarning: torch.ao.quantization is deprecated and will be removed in 2.10.
# For migrations of users:
# 1. Eager mode quantization (torch.ao.quantization.quantize, torch.ao.quantization.quantize_dynamic), please migrate to use torchao eager mode quantize_ API instead
# 2. FX graph mode quantization (torch.ao.quantization.quantize_fx.prepare_fx,torch.ao.quantization.quantize_fx.convert_fx, please migrate to use torchao pt2e quantization API instead (prepare_pt2e, convert_pt2e)
# 3. pt2e quantization has been migrated to torchao (https://github.com/pytorch/ao/tree/main/torchao/quantization/pt2e)
# see https://github.com/pytorch/ao/issues/2259 for more details
#   model_ptq_prepared = prepare_fx(model_fp32, qconfig_dict, example_inputs)
# /home1/ihsiao/.conda/envs/ee599/lib/python3.12/site-packages/torch/ao/quantization/quantize_fx.py:146: FutureWarning: Passing a QConfig dictionary to prepare is deprecated and will not be supported in a future version. Please pass in a QConfigMapping instead.
#   prepared = prepare(
# /home1/ihsiao/.conda/envs/ee599/lib/python3.12/site-packages/torch/ao/quantization/observer.py:246: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# /tmp/SLURM_5221364/ipykernel_3531825/3964949556.py:36: DeprecationWarning: torch.ao.quantization is deprecated and will be removed in 2.10.
# For migrations of users:
# 1. Eager mode quantization (torch.ao.quantization.quantize, torch.ao.quantization.quantize_dynamic), please migrate to use torchao eager mode quantize_ API instead
# 2. FX graph mode quantization (torch.ao.quantization.quantize_fx.prepare_fx,torch.ao.quantization.quantize_fx.convert_fx, please migrate to use torchao pt2e quantization API instead (prepare_pt2e, convert_pt2e)
# 3. pt2e quantization has been migrated to torchao (https://github.com/pytorch/ao/tree/main/torchao/quantization/pt2e)
# see https://github.com/pytorch/ao/issues/2259 for more details
#   model_int8_ptq = convert_fx(model_ptq_prepared)
# GraphModule(
#   (conv1): QuantizedConvReLU2d(3, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.03791094571352005, zero_point=0, padding=(1, 1))
#   (layer1): Module(
#     (0): Module(
#       (conv1): QuantizedConvReLU2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.024302463978528976, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.05443922057747841, zero_point=71, padding=(1, 1))
#     )
#     (1): Module(
#       (conv1): QuantizedConvReLU2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.027135401964187622, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.04607309401035309, zero_point=82, padding=(1, 1))
#     )
#     (2): Module(
#       (conv1): QuantizedConvReLU2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.017572319135069847, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.04234757274389267, zero_point=65, padding=(1, 1))
#     )
#     (3): Module(
#       (conv1): QuantizedConvReLU2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.014226816594600677, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.04187963157892227, zero_point=71, padding=(1, 1))
#     )
#     (4): Module(
#       (conv1): QuantizedConvReLU2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.0134898005053401, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=0.045103590935468674, zero_point=61, padding=(1, 1))
#     )
#   )
#   (layer2): Module(
#     (0): Module(
#       (conv1): QuantizedConvReLU2d(16, 32, kernel_size=(3, 3), stride=(2, 2), scale=0.018070105463266373, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.04054638743400574, zero_point=56, padding=(1, 1))
#       (shortcut): Module(
#         (0): QuantizedConv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), scale=0.03896699473261833, zero_point=54)
#       )
#     )
#     (1): Module(
#       (conv1): QuantizedConvReLU2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.010943109169602394, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.03288819640874863, zero_point=55, padding=(1, 1))
#     )
#     (2): Module(
#       (conv1): QuantizedConvReLU2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.011956269852817059, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.027273567393422127, zero_point=55, padding=(1, 1))
#     )
#     (3): Module(
#       (conv1): QuantizedConvReLU2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.009805282577872276, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.026880774646997452, zero_point=62, padding=(1, 1))
#     )
#     (4): Module(
#       (conv1): QuantizedConvReLU2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.00861816480755806, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.055060792714357376, zero_point=56, padding=(1, 1))
#     )
#   )
#   (layer3): Module(
#     (0): Module(
#       (conv1): QuantizedConvReLU2d(32, 64, kernel_size=(3, 3), stride=(2, 2), scale=0.01867443509399891, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.0527501218020916, zero_point=55, padding=(1, 1))
#       (shortcut): Module(
#         (0): QuantizedConv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), scale=0.02977205254137516, zero_point=56)
#       )
#     )
#     (1): Module(
#       (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.015581375919282436, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.04797181487083435, zero_point=59, padding=(1, 1))
#     )
#     (2): Module(
#       (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.012009508907794952, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.04844752699136734, zero_point=53, padding=(1, 1))
#     )
#     (3): Module(
#       (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.015364990569651127, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.059646300971508026, zero_point=42, padding=(1, 1))
#     )
#     (4): Module(
#       (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.022238323464989662, zero_point=0, padding=(1, 1))
#       (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.08195868134498596, zero_point=35, padding=(1, 1))
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): QuantizedLinear(in_features=64, out_features=10, scale=0.21740244328975677, zero_point=37, qscheme=torch.per_channel_affine)
# )

# %%
import torch

torch.backends.quantized.engine = "fbgemm"  # same backend you used for PTQ

@torch.no_grad()
def evaluate_int8_cpu(model, loader):
    model.eval()
    model.to("cpu")

    correct = 0
    total = 0

    for images, labels in loader:
        images = images.to("cpu")
        labels = labels.to("cpu")

        outputs = model(images)
        _, preds = outputs.max(1)

        total   += labels.size(0)
        correct += (preds == labels).sum().item()

    return 100.0 * correct / total

# ---- actually evaluate your INT8 PTQ-FX model ----
acc = evaluate_int8_cpu(model_int8_ptq, test_loader)
print(f"INT8 PTQ-FX Test Accuracy: {acc:.2f}%")
# Out:
# INT8 PTQ-FX Test Accuracy: 89.40%
